# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A15432/md-inayath--21/blob/main/aiml%20a1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
list1 = [12,"hi",23.4]
np_array = np.array([1, 2, 3, 4, 5])
array1 = np.array([1,90, 13, 14, 15])
array2 = np.array([4, 15, 16, 17, 10])
print(type(list1))
print(type(list1[0]))
print(type(list1[1]))
print(type(list1[2]))
print(type(np_array[2]))
print(type(np_array[1]))
sum = array1+array2
div = array1/array2
mul = array1*array2
print("multiplication of arrays: ",mul)
print("division of arrays: ",div)
print("Summation of arrays: ",sum)
log2_=np.log2(array1[1])
sinn = np.sin(array1[1])
expo = np.exp(array1[1])
print("exponential of elemnt of array1: ",expo)
print("sin of the given array1 index 2: ",sinn)
print("log2 of the element 2 of array1: ",log2_)
# Out:
# <class 'list'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# multiplication of arrays:  [   4 1350  208  238  150]
# division of arrays:  [0.25       6.         0.8125     0.82352941 1.5       ]
# Summation of arrays:  [  5 105  29  31  25]
# exponential of elemnt of array1:  1.2204032943178408e+39
# sin of the given array1 index 2:  0.8939966636005579
# log2 of the element 2 of array1:  6.491853096329675

# %%
#part2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'people': ['kiran', 'arun', 'vijay', 'varun'],
    'age': [25, 30, 35, 40],
    'height': [145, 151, 165, 173],
    'weight': [45, 55, 65, 75]
}

df = pd.DataFrame(data)
plt.figure(figsize=(10, 6))
plt.scatter(df['age'], df['height'], color='blue', s=100, alpha=0.7, edgecolors='black')
plt.title('Scatter Plot of Age vs. Height')
plt.xlabel('Age (years)')
plt.ylabel('Height (cm)')
plt.grid(True)

x = np.arange(len(df['people']))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 7))
bars1 = ax.bar(x - width/2, df['height'], width, label='Height (cm)')
bars2 = ax.bar(x + width/2, df['weight'], width, label='Weight (kg)')

ax.set_xlabel('People')
ax.set_ylabel('Height and Weight')
ax.set_title('Bar Chart of Height and Weight for Each Person')
ax.set_xticks(x)
ax.set_xticklabels(df['people'])
ax.legend()

plt.figure(figsize=(8, 6))

plt.subplot(1, 3, 1)
plt.hist(df['age'], bins=4, color='green', edgecolor='black')
plt.title('Histogram of Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')

plt.subplot(1, 3, 2)
plt.hist(df['height'], bins=4, color='orange', edgecolor='black')
plt.title('Histogram of Height')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')

plt.subplot(1, 3, 3)
plt.hist(df['weight'], bins=4, color='purple', edgecolor='black')
plt.title('Histogram of Weight')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1
# Out:
# E: Package 'libfluidsynth1' has no installation candidate

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %%
# !pip install cartopy
import cartopy
